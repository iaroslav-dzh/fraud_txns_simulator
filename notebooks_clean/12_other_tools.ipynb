# %% [markdown]
# ## Валидатор конфигураций `ConfigsValidator`
# - модуль `data_generator.validator`

# %% [markdown]
# **Тест валидатора конфигураций**

# %%
import os
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

os.chdir("..")

# Общие настройки
with open("./config/base.yaml") as f:
    base_cfg = yaml.safe_load(f)
# Настройки легальных транз.
with open("./config/legit.yaml") as f:
    legit_cfg = yaml.safe_load(f)
# Общие настройки фрода
with open("./config/fraud.yaml") as f:
    fraud_cfg = yaml.safe_load(f)
# Настройки дроп фрода
with open("./config/drops.yaml", encoding="utf8") as f:
    drop_cfg = yaml.safe_load(f)
# Настройки времени
with open("./config/time.yaml") as f:
    time_cfg = yaml.safe_load(f)

# %%
from data_generator.validator import ConfigsValidator

cfg_validator = ConfigsValidator(base_cfg, legit_cfg, fraud_cfg, drop_cfg)

# %% [markdown]
# **get_total_clients**

# %%
cfg_validator.get_total_clients()
# Out:
# 5369

# %% [markdown]
# **estimate_legit_clients**

# %%
cfg_validator.estimate_legit_clients()
# Out:
# 7500

# %% [markdown]
# **model_legit_txns_num_dist**

# %%
legit_dist = cfg_validator.model_legit_txns_num_dist()
legit_dist.ppf(0.99), legit_dist.mean(), legit_dist.std()
# Out:
# (np.float64(10822.162378214074),
#  np.float64(10337.778922506115),
#  np.float64(208.21626082370474))

# %% [markdown]
# **estimate_legit_txns_max**

# %%
cfg_validator.estimate_legit_txns_max()
# Out:
# 10981

# %% [markdown]
# **estimate_compr_clients**

# %%
cfg_validator.estimate_compr_clients()
# Out:
# 12208

# %% [markdown]
# **validate_legit_txn_num**

# %%
cfg_validator.validate_legit_txn_num()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 cfg_validator.validate_legit_txn_num()
#
# File ~\My_documents\Education\projects\fraud_detection_01\modules\data_generator\validator.py:112, in ConfigsValidator.validate_legit_txn_num(self)
#     109 legit_clients = self.estimate_legit_clients()
#     111 if legit_clients > total_clients:
# --> 112     raise ValueError(f"""Desired legit txns number is too large: {total_txns}.
#     113     Clients number needed for generation: {legit_clients}.
#     114     Available clients: {total_clients}.
#     115     Either reduce legit txns number or increase avg txn number per client
#     116     or both.""")
#     118 print("Legit txns number config is OK")
#
# ValueError: Desired legit txns number is too large: 150000.
#             Clients number needed for generation: 7500.
#             Available clients: 5369.
#             Either reduce legit txns number or increase avg txn number per client
#             or both.

# %% [markdown]
# **validate_comp_rate**

# %%
cfg_validator.validate_comp_rate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cfg_validator.validate_comp_rate()
#
# File ~\My_documents\Education\projects\fraud_detection_01\modules\data_generator\validator.py:131, in ConfigsValidator.validate_comp_rate(self)
#     128 clients_count = self.estimate_compr_clients()
#     130 if clients_count > est_clients:
# --> 131     raise ValueError(f"""Estimated maximum possible number of clients that might be needed to generate
#     132     'compromised client' fraud transactions: {clients_count}.
#     133     Estimated number of clients required for generating legitimate transactions: {est_clients}.
#     134
#     135     The number of compromised fraud clients cannot be less than the number required
#     136     for legitimate transaction generation.
#     137
#     138     Please either:
#     139     1. Decrease the 'compr_client' rate and/or the overall fraud rate in configs/fraud.yaml
#     140     2. Reduce the average number of legitimate transactions per client in legit.yaml
#     141     """)
#     143 print("Compromised fraud rate config is OK")
#
# ValueError: Estimated maximum possible number of clients that might be needed to generate
#             'compromised client' fraud transactions: 1012.
#             Estimated number of clients required for generating legitimate transactions: 1000.
#
#             The number of compromised fraud clients cannot be less than the number required
#             for legitimate transaction generation.
#
#             Please either:
#             1. Decrease the 'compr_client' rate and/or the overall fraud rate in configs/fraud.yaml
#             2. Reduce the average number of legitimate transactions per client in legit.yaml

# %% [markdown]
# **validate_drops_rate**

# %%
cfg_validator.validate_drops_rate()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 cfg_validator.validate_drops_rate()
#
# File ~\My_documents\Education\projects\fraud_detection_01\modules\data_generator\validator.py:174, in ConfigsValidator.validate_drops_rate(self)
#     171 remainder = max(0, total_clients - (legit_clients + compr_clients))
#     173 if remainder < total_drops:
# --> 174     raise ValueError(f"""Total clients number needed for drop fraud generation
#     175     exceeds the available clients number.
#     176     Clients number needed for drops: {total_drops}
#     177     Available clients: {remainder}
#     178     Legit txns clients: {legit_clients}
#     179     Compr fraud clients: {compr_clients}
#     180     Please eitehr:
#     181     1. Reduce total fraud rate.
#     182     2. Reduce legit txns number""")
#     184 print("Drop fraud rate config is OK")
#
# ValueError: Total clients number needed for drop fraud generation
#             exceeds the available clients number.
#             Clients number needed for drops: 654
#             Available clients: 0
#             Legit txns clients: 7500
#             Compr fraud clients: 12208
#             Please eitehr:
#             1. Reduce total fraud rate.
#             2. Reduce legit txns number

# %% [markdown]
# **validate_all**

# %%
import os
import yaml
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

os.chdir("..")

# Общие настройки
with open("./config/base.yaml") as f:
    base_cfg = yaml.safe_load(f)
# Настройки легальных транз.
with open("./config/legit.yaml") as f:
    legit_cfg = yaml.safe_load(f)
# Общие настройки фрода
with open("./config/fraud.yaml") as f:
    fraud_cfg = yaml.safe_load(f)
# Настройки дроп фрода
with open("./config/drops.yaml", encoding="utf8") as f:
    drop_cfg = yaml.safe_load(f)
# Настройки времени
with open("./config/time.yaml") as f:
    time_cfg = yaml.safe_load(f)
    
from data_generator.validator import ConfigsValidator

cfg_validator = ConfigsValidator(base_cfg, legit_cfg, fraud_cfg, drop_cfg)

# %%
cfg_validator.validate_all()
# Out:
# Legit txns number config is OK
# Compromised fraud rate config is OK
# Drop fraud rate config is OK
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 cfg_validator.validate_all()
#
# File ~\My_documents\Education\projects\fraud_detection_01\modules\data_generator\validator.py:218, in ConfigsValidator.validate_all(self)
#     216 self.validate_comp_rate()
#     217 self.validate_drops_rate()
# --> 218 self.assert_legit_time_limits()
#
# File ~\My_documents\Education\projects\fraud_detection_01\modules\data_generator\validator.py:205, in ConfigsValidator.assert_legit_time_limits(self)
#     197 assert offline_time_diff > general_diff, \
#     198     f"""offline_time_diff must not be lower than general_diff.
#     199     {offline_time_diff} vs {general_diff} Check configs in legit.yaml"""
#     201 assert offline_time_diff > online_time_diff, \
#     202     f"""offline_time_diff must not be lower than online_time_diff.
#     203     {offline_time_diff} vs {online_time_diff} Check configs in legit.yaml"""
# --> 205 assert general_diff > online_time_diff, \
#     206     f"""general_diff must not be lower than online_time_diff.
#     207     {general_diff} vs {online_time_diff} Check configs in legit.yaml"""
#     209 print("Legit min time intervals config is OK")
#
# AssertionError: general_diff must not be lower than online_time_diff.
#             4 vs 6 Check configs in legit.yaml

# %% [markdown]
# **assert_legit_time_limits**

# %%
cfg_validator.assert_legit_time_limits()
# Out:
# Legit time limits config is OK

# %%
legit_cfg: dict. Конфиги из .yaml
base_cfg: dict. Конфиги из .yaml
fraud_cfg: dict. Конфиги из .yaml
drop_cfg: dict. Конфиги из .yaml
total_clients: dict. Конфиги из .yaml

# %% [markdown]
# # Класс `AllTxnsRecorder`
# - модуль `data_generator.recorder`
# - Сборка целого датафрейма из всех созданных транзакций: легальных, фрода все типов
# - Запись собранного датафрейма в файл в двух директориях: текущей генерации и последней генерации

# %%
import os
import pandas as pd
os.chdir("..")

from data_generator.utils import load_configs
from data_generator.recorder import AllTxnsRecorder


# Общие настройки
base_cfg = load_configs("./config/base.yaml")
# Настройки легальных транзакций
legit_cfg = load_configs("./config/legit.yaml")
compr_cfg = load_configs("./config/compr.yaml")
# Настройки дроп фрода
drops_cfg = load_configs("./config/drops.yaml")

run_dir = "./data/generated/history/generation_run_2025-07-21_154309" # make_dir_for_run(base_cfg=base_cfg)
all_recorder = AllTxnsRecorder(base_cfg, legit_cfg, compr_cfg, drops_cfg, \
                         run_dir)
print(run_dir)
print("ready for test")
# Out:
# ./data/generated/history/generation_run_2025-07-21_154309
# ready for test

# %%
# 
leg_fm_recorder = all_recorder.read_legit()
leg_fm_recorder.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       2853 2025-01-01 00:43:00  1735692180  1658.84  purchase    ecom
# 1        858 2025-01-01 00:51:00  1735692660  1131.71  purchase     POS
#
#         category  online  merchant_id    trans_city  trans_lat  trans_lon  \
# 0   shopping_net    True       6952.0  Магнитогорск  53.407189  58.979143
# 1  gas_transport   False       4438.0       Барнаул  53.294364  83.771525
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0     2.60.10.139     4887.0      NaN     False          False  approved
# 1  not applicable        NaN      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
leg_path = os.path.join(run_dir, "legit", "legit_txns.parquet")
leg_fm_direct = pd.read_parquet(leg_path)
leg_fm_direct.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       2853 2025-01-01 00:43:00  1735692180  1658.84  purchase    ecom
# 1        858 2025-01-01 00:51:00  1735692660  1131.71  purchase     POS
#
#         category  online  merchant_id    trans_city  trans_lat  trans_lon  \
# 0   shopping_net    True       6952.0  Магнитогорск  53.407189  58.979143
# 1  gas_transport   False       4438.0       Барнаул  53.294364  83.771525
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0     2.60.10.139     4887.0      NaN     False          False  approved
# 1  not applicable        NaN      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(leg_fm_recorder.shape, leg_fm_direct.shape)
assert leg_fm_recorder.shape == leg_fm_direct.shape
leg_shape = leg_fm_recorder.shape
# Out:
# (10351, 19) (10351, 19)

# %%
compr_fm_recorder = all_recorder.read_compromised()
compr_fm_recorder.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0        521 2025-01-20 09:41:50  1737366110  33000.0  purchase    ecom
# 1       1584 2025-01-19 20:55:02  1737320102   2777.0  purchase     POS
#
#    category  online  merchant_id trans_city  trans_lat   trans_lon  \
# 0  misc_net    True       6821.0    Саратов  51.530376   45.953026
# 1      home   False       2456.0     Якутск  62.115507  129.729329
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0     5.3.255.240    11265.0      NaN      True          False  declined
# 1  not applicable        NaN      NaN      True          False  declined
#
#                             rule
# 0  new_ip_and_device_high_amount
# 1                fast_geo_change

# %%
compr_path = os.path.join(run_dir, "compromised", "compr_client_txns.parquet")
compr_fm_direct = pd.read_parquet(compr_path)
compr_fm_direct.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0        521 2025-01-20 09:41:50  1737366110  33000.0  purchase    ecom
# 1       1584 2025-01-19 20:55:02  1737320102   2777.0  purchase     POS
#
#    category  online  merchant_id trans_city  trans_lat   trans_lon  \
# 0  misc_net    True       6821.0    Саратов  51.530376   45.953026
# 1      home   False       2456.0     Якутск  62.115507  129.729329
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0     5.3.255.240    11265.0      NaN      True          False  declined
# 1  not applicable        NaN      NaN      True          False  declined
#
#                             rule
# 0  new_ip_and_device_high_amount
# 1                fast_geo_change

# %%
print(compr_fm_recorder.shape, compr_fm_direct.shape)
assert compr_fm_recorder.shape == compr_fm_direct.shape
compr_shape = compr_fm_recorder.shape
# Out:
# (180, 19) (180, 19)

# %%
dist_fm_recorder = all_recorder.read_dist_drops()
dist_fm_recorder.head(2)
# Out:
#    client_id            txn_time   unix_time   amount        type   channel  \
# 0       2275 2025-01-08 16:39:00  1736354340  24500.0     inbound  transfer
# 1       2275 2025-01-08 17:17:00  1736356620  11400.0  withdrawal       ATM
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1  not applicable   False          NaN     Новокузнецк  53.794276  87.214405
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN  12152.0     False          False  approved
# 1  not applicable        NaN  12152.0     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
dist_path = os.path.join(run_dir, "dist_drops", "dist_drop_txns.parquet")
dist_fm_direct = pd.read_parquet(dist_path)
dist_fm_direct.head(2)
# Out:
#    client_id            txn_time   unix_time   amount        type   channel  \
# 0       2275 2025-01-08 16:39:00  1736354340  24500.0     inbound  transfer
# 1       2275 2025-01-08 17:17:00  1736356620  11400.0  withdrawal       ATM
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1  not applicable   False          NaN     Новокузнецк  53.794276  87.214405
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN  12152.0     False          False  approved
# 1  not applicable        NaN  12152.0     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(dist_fm_recorder.shape, dist_fm_direct.shape)
assert dist_fm_recorder.shape == dist_fm_direct.shape
dist_shape = dist_fm_recorder.shape
# Out:
# (30, 19) (30, 19)

# %%
purch_fm_recorder = all_recorder.read_purch_drops()
purch_fm_recorder.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type   channel  \
# 0       1791 2025-01-18 05:06:00  1737176760  23900.0   inbound  transfer
# 1       1791 2025-01-18 07:15:00  1737184500  21000.0  purchase      ecom
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1    shopping_net    True       6850.0  Ростов-на-Дону  47.222436  39.718787
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN  11688.0     False          False  approved
# 1      2.60.6.153     3063.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
purch_path = os.path.join(run_dir, "purch_drops", "purch_drop_txns.parquet")
purch_fm_direct = pd.read_parquet(purch_path)
purch_fm_direct.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type   channel  \
# 0       1791 2025-01-18 05:06:00  1737176760  23900.0   inbound  transfer
# 1       1791 2025-01-18 07:15:00  1737184500  21000.0  purchase      ecom
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1    shopping_net    True       6850.0  Ростов-на-Дону  47.222436  39.718787
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN  11688.0     False          False  approved
# 1      2.60.6.153     3063.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(purch_fm_recorder.shape, purch_fm_direct.shape)
assert purch_fm_recorder.shape == purch_fm_direct.shape
purch_shape = purch_fm_recorder.shape
# Out:
# (30, 19) (30, 19)

# %% [markdown]
# **build_and_write**

# %%
all_recorder.build_and_write()
# Out:
# Building and writing all txns dataframe... completed.. |

# %%
total_shape = sum([leg_shape[0], compr_shape[0], dist_shape[0], purch_shape[0]])
total_shape
# Out:
# 10591

# %%
all_recorder.whole_df.shape
# Out:
# (10591, 19)

# %%
all_txns_fm_recorder = all_recorder.whole_df

# %%
path = os.path.join(run_dir, "all_txns.parquet")
all_txns_fm_direct = pd.read_parquet(path)
all_txns_fm_direct.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       2853 2025-01-01 00:43:00  1735692180  1658.84  purchase    ecom
# 1        858 2025-01-01 00:51:00  1735692660  1131.71  purchase     POS
#
#         category  online  merchant_id    trans_city  trans_lat  trans_lon  \
# 0   shopping_net    True       6952.0  Магнитогорск  53.407189  58.979143
# 1  gas_transport   False       4438.0       Барнаул  53.294364  83.771525
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0     2.60.10.139     4887.0      NaN     False          False  approved
# 1  not applicable        NaN      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(all_txns_fm_recorder.shape, all_txns_fm_direct.shape)
assert all_txns_fm_recorder.shape == all_txns_fm_direct.shape
all_txns_shape = all_txns_fm_recorder.shape
# Out:
# (10591, 19) (10591, 19)

# %%
all_path = base_cfg["data_paths"]["generated"]["all_txns"]
all_txns_latest = pd.read_parquet(all_path)
all_txns_latest.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       2853 2025-01-01 00:43:00  1735692180  1658.84  purchase    ecom
# 1        858 2025-01-01 00:51:00  1735692660  1131.71  purchase     POS
#
#         category  online  merchant_id    trans_city  trans_lat  trans_lon  \
# 0   shopping_net    True       6952.0  Магнитогорск  53.407189  58.979143
# 1  gas_transport   False       4438.0       Барнаул  53.294364  83.771525
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0     2.60.10.139     4887.0      NaN     False          False  approved
# 1  not applicable        NaN      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(all_txns_latest.shape, all_txns_fm_direct.shape)
assert all_txns_latest.shape == all_txns_fm_direct.shape
all_txns_shape = all_txns_latest.shape
# Out:
# (10591, 19) (10591, 19)

# %% [markdown]
# # **Готовый генератор `run`**
# - генерация всех типов транзакций, запись в файлы
# - сборка единого файла с транзакциями

# %%
import os
import pandas as pd
import yaml
os.chdir("..")

# Общие настройки
with open("./config/base.yaml") as f:
    base_cfg = yaml.safe_load(f)

# %%
hist_dir = "./data/generated/history/"
run_folder = os.listdir(hist_dir)[-1]
run_dir = os.path.join(hist_dir, run_folder)

# %%
leg_path = os.path.join(run_dir, "legit", "legit_txns.parquet")
leg_fm_run = pd.read_parquet(leg_path)
leg_fm_run.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       3620 2025-01-01 00:35:00  1735691700  2200.00  purchase    ecom
# 1       3545 2025-01-01 00:49:00  1735692540  1015.27  purchase    ecom
#
#        category  online  merchant_id trans_city  trans_lat  trans_lon  \
# 0  shopping_net    True       6855.0     Липецк  52.610303  39.594627
# 1   grocery_net    True       6831.0     Самара  53.195166  50.106769
#
#       trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  2.60.13.103     6224.0      NaN     False          False  approved
# 1   2.60.13.33     6093.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
data_paths = base_cfg["data_paths"]
leg_latest_path = data_paths["generated"]["legit_txns"]
leg_latest = pd.read_parquet(leg_latest_path)
leg_latest.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       3620 2025-01-01 00:35:00  1735691700  2200.00  purchase    ecom
# 1       3545 2025-01-01 00:49:00  1735692540  1015.27  purchase    ecom
#
#        category  online  merchant_id trans_city  trans_lat  trans_lon  \
# 0  shopping_net    True       6855.0     Липецк  52.610303  39.594627
# 1   grocery_net    True       6831.0     Самара  53.195166  50.106769
#
#       trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  2.60.13.103     6224.0      NaN     False          False  approved
# 1   2.60.13.33     6093.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(leg_fm_run.shape, leg_latest.shape)
assert leg_fm_run.shape == leg_latest.shape
leg_shape = leg_fm_run.shape
# Out:
# (10367, 19) (10367, 19)

# %%
compr_path = os.path.join(run_dir, "compromised", "compr_client_txns.parquet")
compr_fm_run = pd.read_parquet(compr_path)
compr_fm_run.head(2)
# Out:
#    client_id            txn_time   unix_time    amount      type channel  \
# 0        628 2025-01-19 10:23:58  1737282238   7831.75  purchase    ecom
# 1       3094 2025-01-19 21:32:49  1737322369  12580.00  purchase    ecom
#
#    category  online  merchant_id            trans_city  trans_lat   trans_lon  \
# 0  misc_net    True       6915.0  Комсомольск-на-Амуре  50.550011  137.007929
# 1  misc_net    True       6854.0              Кемерово  55.390972   86.046786
#
#     trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0   5.8.6.46    11756.0      NaN      True          False  declined
# 1  5.8.2.104    12095.0      NaN      True          False  declined
#
#                          rule
# 0      fast_geo_change_online
# 1  new_device_and_high_amount

# %%
data_paths = base_cfg["data_paths"]
compr_latest_path = data_paths["generated"]["compr_client_txns"]
compr_latest = pd.read_parquet(compr_latest_path)
compr_latest.head(2)
# Out:
#    client_id            txn_time   unix_time    amount      type channel  \
# 0        628 2025-01-19 10:23:58  1737282238   7831.75  purchase    ecom
# 1       3094 2025-01-19 21:32:49  1737322369  12580.00  purchase    ecom
#
#    category  online  merchant_id            trans_city  trans_lat   trans_lon  \
# 0  misc_net    True       6915.0  Комсомольск-на-Амуре  50.550011  137.007929
# 1  misc_net    True       6854.0              Кемерово  55.390972   86.046786
#
#     trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0   5.8.6.46    11756.0      NaN      True          False  declined
# 1  5.8.2.104    12095.0      NaN      True          False  declined
#
#                          rule
# 0      fast_geo_change_online
# 1  new_device_and_high_amount

# %%
print(compr_fm_run.shape, compr_latest.shape)
assert compr_fm_run.shape == compr_latest.shape
compr_shape = compr_fm_run.shape
# Out:
# (156, 19) (156, 19)

# %%
dist_path = os.path.join(run_dir, "dist_drops", "dist_drop_txns.parquet")
dist_fm_run = pd.read_parquet(dist_path)
dist_fm_run.head(2)
# Out:
#    client_id            txn_time   unix_time   amount        type   channel  \
# 0       5175 2025-01-09 12:03:00  1736424180  41700.0     inbound  transfer
# 1       5175 2025-01-09 13:20:00  1736428800  41700.0  withdrawal       ATM
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1  not applicable   False          NaN       Чебоксары  56.143938  47.248872
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN    14648     False          False  approved
# 1  not applicable        NaN    14648     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
data_paths = base_cfg["data_paths"]
dist_latest_path = data_paths["generated"]["dist_drop_txns"]
dist_latest = pd.read_parquet(dist_latest_path)
dist_latest.head(2)
# Out:
#    client_id            txn_time   unix_time   amount        type   channel  \
# 0       5175 2025-01-09 12:03:00  1736424180  41700.0     inbound  transfer
# 1       5175 2025-01-09 13:20:00  1736428800  41700.0  withdrawal       ATM
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1  not applicable   False          NaN       Чебоксары  56.143938  47.248872
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN    14648     False          False  approved
# 1  not applicable        NaN    14648     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(dist_latest.shape, dist_fm_run.shape)
assert dist_latest.shape == dist_fm_run.shape
dist_shape = dist_latest.shape
# Out:
# (32, 19) (32, 19)

# %%
purch_path = os.path.join(run_dir, "purch_drops", "purch_drop_txns.parquet")
purch_fm_run = pd.read_parquet(purch_path)
purch_fm_run.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type   channel  \
# 0       4649 2025-01-15 16:38:00  1736959080  42500.0   inbound  transfer
# 1       4649 2025-01-15 17:29:00  1736962140  28000.0  purchase      ecom
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1        misc_net    True       6881.0          Курган  55.444345  65.316134
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN  14394.0     False          False  approved
# 1      2.60.17.43     7969.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
data_paths = base_cfg["data_paths"]
purch_latest_path = data_paths["generated"]["purch_drop_txns"]
purch_latest = pd.read_parquet(purch_latest_path)
purch_latest.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type   channel  \
# 0       4649 2025-01-15 16:38:00  1736959080  42500.0   inbound  transfer
# 1       4649 2025-01-15 17:29:00  1736962140  28000.0  purchase      ecom
#
#          category  online  merchant_id      trans_city  trans_lat  trans_lon  \
# 0  not applicable    True          NaN  not applicable        NaN        NaN
# 1        misc_net    True       6881.0          Курган  55.444345  65.316134
#
#          trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  not applicable        NaN  14394.0     False          False  approved
# 1      2.60.17.43     7969.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(purch_fm_run.shape, purch_latest.shape)
assert purch_fm_run.shape == purch_latest.shape
purch_shape = purch_fm_run.shape
# Out:
# (34, 19) (34, 19)

# %%
total_shape = sum([leg_shape[0], compr_shape[0], dist_shape[0], purch_shape[0]])
total_shape
# Out:
# 10589

# %%
path = os.path.join(run_dir, "all_txns.parquet")
all_txns_fm_run = pd.read_parquet(path)
all_txns_fm_run.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       3620 2025-01-01 00:35:00  1735691700  2200.00  purchase    ecom
# 1       3545 2025-01-01 00:49:00  1735692540  1015.27  purchase    ecom
#
#        category  online  merchant_id trans_city  trans_lat  trans_lon  \
# 0  shopping_net    True       6855.0     Липецк  52.610303  39.594627
# 1   grocery_net    True       6831.0     Самара  53.195166  50.106769
#
#       trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  2.60.13.103     6224.0      NaN     False          False  approved
# 1   2.60.13.33     6093.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
all_path = base_cfg["data_paths"]["generated"]["all_txns"]
all_txns_latest = pd.read_parquet(all_path)
all_txns_latest.head(2)
# Out:
#    client_id            txn_time   unix_time   amount      type channel  \
# 0       3620 2025-01-01 00:35:00  1735691700  2200.00  purchase    ecom
# 1       3545 2025-01-01 00:49:00  1735692540  1015.27  purchase    ecom
#
#        category  online  merchant_id trans_city  trans_lat  trans_lon  \
# 0  shopping_net    True       6855.0     Липецк  52.610303  39.594627
# 1   grocery_net    True       6831.0     Самара  53.195166  50.106769
#
#       trans_ip  device_id  account  is_fraud  is_suspicious    status  \
# 0  2.60.13.103     6224.0      NaN     False          False  approved
# 1   2.60.13.33     6093.0      NaN     False          False  approved
#
#              rule
# 0  not applicable
# 1  not applicable

# %%
print(all_txns_latest.shape, all_txns_fm_run.shape)
assert all_txns_latest.shape == all_txns_fm_run.shape
all_txns_shape = all_txns_latest.shape
# Out:
# (10589, 19) (10589, 19)
